# %% [markdown]
# # Demonstration of geomaps module
# Module that given a state and a set of points produces a map
#
# Derived from https://rosenfelder.ai/create-maps-with-python/

# %% [markdown]
# ## Import the module and other libraries

# %%
import pandas as pd

# %%
import geo_maps as g_m

# %% [markdown]
# ## Define geopandas dataframe with the set of points for a state

# %%
gpd_points = g_m.get_state_zips('MT')

# %%
gpd_points.head()
# Out:
#      Zip            City State  Timezone  Daylight savings time flag  \
# 0  59910         Big Arm    MT        -7                           1
# 1  59004         Ashland    MT        -7                           1
# 2  59231     Saint Marie    MT        -7                           1
# 3  59638  Jefferson City    MT        -7                           1
# 4  59115        Billings    MT        -7                           1
#
#                       geometry
# 0  POINT (-114.30638 47.80214)
# 1  POINT (-106.99199 46.01797)
# 2  POINT (-106.53357 48.40467)
# 3  POINT (-112.14074 46.37653)
# 4  POINT (-108.19451 45.97829)

# %% [markdown]
# ## Call the functin to create the map

# %%
state_gpd = g_m.create_map('Montana', gpd_points)
# Out:
# /home/gino/.local/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# 44.358221 49.00139
# -116.050003 -104.039138
# /home/gino/.local/lib/python3.8/site-packages/pyproj/crs/crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# ...

# %%
from pyproj import Proj, transform

inProj = Proj(init='epsg:3857')
outProj = Proj(init='epsg:4326')
x1,y1 = -11705274.6374,4826473.6922
x2,y2 = transform(inProj,outProj,x1,y1)
print (x2,y2)

# %%
state_bb_file = 'states_bounding_boxes.csv'
states_bb_df = pd.read_csv(state_bb_file)
state_bb_df = states_bb_df[states_bb_df['NAME']=='Montana']

# %%
state_bb_df.head()

# %%
list(state_bb_df.xmin)
